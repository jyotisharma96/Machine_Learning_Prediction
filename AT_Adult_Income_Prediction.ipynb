# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
adult = pd.read_csv('adult.data', header = None)

# %%
adult.head()
# Out:
#    0                  1       2           3   4                    5   \
# 0  39          State-gov   77516   Bachelors  13        Never-married
# 1  50   Self-emp-not-inc   83311   Bachelors  13   Married-civ-spouse
# 2  38            Private  215646     HS-grad   9             Divorced
# 3  53            Private  234721        11th   7   Married-civ-spouse
# 4  28            Private  338409   Bachelors  13   Married-civ-spouse
#
#                    6               7       8        9     10  11  12  \
# 0        Adm-clerical   Not-in-family   White     Male  2174   0  40
# 1     Exec-managerial         Husband   White     Male     0   0  13
# 2   Handlers-cleaners   Not-in-family   White     Male     0   0  40
# 3   Handlers-cleaners         Husband   Black     Male     0   0  40
# 4      Prof-specialty            Wife   Black   Female     0   0  40
#
#                13      14
# 0   United-States   <=50K
# 1   United-States   <=50K
# 2   United-States   <=50K
# ...

# %%
col_names = ['age', 'workclass', 'fnlwgt', 'education', 'education_num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital gain', 'capital loss', 'hours_per_week', 'native country', 'income']

# %%
adult.columns = col_names

# %%
adult.head()
# Out:
#    age          workclass  fnlwgt   education  education_num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital gain  capital loss  hours_per_week  native country  income
# 0          2174             0              40   United-States   <=50K
# ...

# %%
adult.shape
# Out:
# (32561, 15)

# %%
adult.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education_num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital gain    32561 non-null  int64
#  11  capital loss    32561 non-null  int64
#  12  hours_per_week  32561 non-null  int64
#  13  native country  32561 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
adult.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education_num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital gain', 'capital loss', 'hours_per_week', 'native country',
#        'income'],
#       dtype='object')

# %%
adult['income'].value_counts()
# Out:
#  <=50K    24720
#  >50K      7841
# Name: income, dtype: int64

# %%
adult.describe()
# Out:
#                 age        fnlwgt  education_num  capital gain  capital loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours_per_week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
for i in adult.columns:
    print(adult[i].unique(),"\t",adult[i].nunique())
# Out:
# [39 50 38 53 28 37 49 52 31 42 30 23 32 40 34 25 43 54 35 59 56 19 20 45
#  22 48 21 24 57 44 41 29 18 47 46 36 79 27 67 33 76 17 55 61 70 64 71 68
#  66 51 58 26 60 90 75 65 77 62 63 80 72 74 69 73 81 78 88 82 83 84 85 86
#  87] 	 73
# [' State-gov' ' Self-emp-not-inc' ' Private' ' Federal-gov' ' Local-gov'
#  ' ?' ' Self-emp-inc' ' Without-pay' ' Never-worked'] 	 9
# [ 77516  83311 215646 ...  34066  84661 257302] 	 21648
# [' Bachelors' ' HS-grad' ' 11th' ' Masters' ' 9th' ' Some-college'
#  ' Assoc-acdm' ' Assoc-voc' ' 7th-8th' ' Doctorate' ' Prof-school'
#  ' 5th-6th' ' 10th' ' 1st-4th' ' Preschool' ' 12th'] 	 16
# [13  9  7 14  5 10 12 11  4 16 15  3  6  2  1  8] 	 16
# [' Never-married' ' Married-civ-spouse' ' Divorced'
#  ' Married-spouse-absent' ' Separated' ' Married-AF-spouse' ' Widowed'] 	 7
# [' Adm-clerical' ' Exec-managerial' ' Handlers-cleaners' ' Prof-specialty'
#  ' Other-service' ' Sales' ' Craft-repair' ' Transport-moving'
# ...

# %%
from numpy import nan
adult = adult.replace(' ?',nan)
adult.head()
# Out:
#    age          workclass  fnlwgt   education  education_num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital gain  capital loss  hours_per_week  native country  income
# 0          2174             0              40   United-States   <=50K
# ...

# %%
adult.isnull().sum()
# Out:
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# education_num        0
# marital-status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital gain         0
# capital loss         0
# hours_per_week       0
# native country     583
# income               0
# dtype: int64

# %%
null_values = adult.isnull().sum()
null_values = pd.DataFrame(null_values,columns=['null'])
j=1
sum_total=len(adult)
null_values['percentage'] = null_values['null']/sum_total
round(null_values*100,3).sort_values('percentage',ascending=False)
# Out:
#                   null  percentage
# occupation      184300       5.660
# workclass       183600       5.639
# native country   58300       1.790
# age                  0       0.000
# fnlwgt               0       0.000
# education            0       0.000
# education_num        0       0.000
# marital-status       0       0.000
# relationship         0       0.000
# race                 0       0.000
# sex                  0       0.000
# capital gain         0       0.000
# capital loss         0       0.000
# hours_per_week       0       0.000
# income               0       0.000

# %%
adult['occupation'].fillna(adult['occupation'].mode()[0],inplace = True)

# %%
adult['workclass'].fillna(adult['workclass'].mode()[0],inplace = True)

# %%
adult['native country'].fillna(adult['native country'].mode()[0],inplace = True)

# %%
null_values = adult.isnull().sum()
null_values = pd.DataFrame(null_values,columns=['null'])
j=1
sum_total=len(adult)
null_values['percentage'] = null_values['null']/sum_total
round(null_values*100,3).sort_values('percentage',ascending=False)
# Out:
#                 null  percentage
# age                0         0.0
# workclass          0         0.0
# fnlwgt             0         0.0
# education          0         0.0
# education_num      0         0.0
# marital-status     0         0.0
# occupation         0         0.0
# relationship       0         0.0
# race               0         0.0
# sex                0         0.0
# capital gain       0         0.0
# capital loss       0         0.0
# hours_per_week     0         0.0
# native country     0         0.0
# income             0         0.0

# %%
adult['age'].hist(figsize = (6,6))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#warnings
import warnings
warnings.simplefilter(action='ignore')

# %%
sns.distplot(adult['fnlwgt'].dropna(), bins = 50, color ='Green')
plt.title('Final Weightage Distribution')
# Out:
# Text(0.5, 1.0, 'Final Weightage Distribution')

# %%
adult['fnlwgt'].hist(figsize = (5,5))
plt.show()

# %%
adult['capital gain'].hist(figsize=(5,5))
plt.show()

# %%
adult['capital loss'].hist(figsize=(5,5))
plt.show()

# %%
ax = sns.scatterplot(x="capital gain", y="capital loss", data=adult, color = 'green')

# %%
adult['hours_per_week'].hist(figsize=(5,5))
plt.show()

# %%
plt.figure(figsize=(12,5))
sns.countplot(x='workclass',data=adult)
# Out:
# <AxesSubplot:xlabel='workclass', ylabel='count'>

# %%
plt.figure(figsize=(12,5))

total = float(len(adult['income']))

a = sns.countplot(x='workclass',data=adult)

for f in a.patches:
    height = f.get_height()
    a.text(f.get_x() + f.get_width()/2., height+3, '{:1.2f}'.format((height/total)*100),ha="center")
plt.show()

# %%
plt.figure(figsize=(20,5))

a= float(len(['income']))

a= sns.countplot(x='education',data=adult)
for s in a.patches:
    height = s.get_height()
    a.text(s.get_x()+s.get_width()/2.,height+3,'{:1.2f}'.format((height/total)*100),ha='center')
plt.show()

# %%
plt.figure(figsize=(15,8))
total = float(len(adult))

ax = sns.countplot(x="marital-status", data=adult)
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:1.2f}'.format((height/total)*100),
            ha="center") 
plt.show()

# %%
plt.figure(figsize=(22,8))
total = float(len(adult) )

ax = sns.countplot(x="occupation", data=adult)
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:1.2f}'.format((height/total)*100),
            ha="center") 
plt.show()

# %%
plt.figure(figsize=(15,8))
total = float(len(adult) )

ax = sns.countplot(x="relationship", data=adult)
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:1.2f}'.format((height/total)*100),
            ha="center") 
plt.show()

# %%
plt.figure(figsize=(15,8))
total = float(len(adult) )

ax = sns.countplot(x="race", data=adult)
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:1.2f}'.format((height/total)*100),
            ha="center") 
plt.show()

# %%
plt.figure(figsize=(5,5))
total = float(len(adult) )

ax = sns.countplot(x="sex", data=adult)
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:1.2f}'.format((height/total)*100),
            ha="center") 
plt.show()

# %%
plt.figure(figsize=(5,5))
total = float(len(adult) )

ax = sns.countplot(x="income", data=adult)
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:1.2f}'.format((height/total)*100),
            ha="center") 
plt.show()

# %%
fig = plt.figure(figsize=(5,5))
sns.boxplot(x='income',y='age',data=adult).set_title('Box plot of INCOME and AGE')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
fig = plt.figure(figsize=(10,5))
sns.countplot(x='workclass',hue ='income',data=adult).set_title("workclass vs count")
# Out:
# Text(0.5, 1.0, 'workclass vs count')

# %%
plt.figure(figsize=(5,5))
sns.boxplot(x="income", y="capital gain", data=adult)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.boxplot(x="income", y="capital loss", data=adult)
plt.show()

# %%
plt.figure(figsize=(10,7))
sns.countplot(x="relationship", hue="income", data=adult)
# Out:
# <AxesSubplot:xlabel='relationship', ylabel='count'>

# %%
plt.figure(figsize=(12,5))
total = float(len(adult["income"]) )

ax = sns.countplot(x="workclass", hue="income", data=adult)
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:1.2f}'.format((height/total)*100),
            ha="center") 
plt.show()
# Out:
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values

# %%
sns.catplot(y="education", hue="income", kind="count", edgecolor=".6", data=adult);

# %%
sns.heatmap(adult.corr())
# Out:
# <AxesSubplot:>

# %%
adult.head(1)
# Out:
#    age   workclass  fnlwgt   education  education_num  marital-status  \
# 0   39   State-gov   77516   Bachelors             13   Never-married
#
#       occupation    relationship    race    sex  capital gain  capital loss  \
# 0   Adm-clerical   Not-in-family   White   Male          2174             0
#
#    hours_per_week  native country  income
# 0              40   United-States   <=50K

# %%
adult['education'].replace([' 11th', ' 9th', ' 7th-8th', ' 5th-6th', ' 10th', ' 1st-4th', ' Preschool', ' 12th'],
                             'School', inplace = True)

# %%
adult['education'].unique()
# Out:
# array([' Bachelors', ' HS-grad', 'School', ' Masters', ' Some-college',
#        ' Assoc-acdm', ' Assoc-voc', ' Doctorate', ' Prof-school'],
#       dtype=object)

# %%
adult['race'].replace([' Black', ' Asian-Pac-Islander', ' Amer-Indian-Eskimo', ' Other'],' Other', inplace = True)

# %%
adult['race'].unique()
# Out:
# array([' White', ' Other'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
categorical = ['workclass','education', 'marital-status', 'occupation', 'relationship',
               'race', 'sex','native country','income']
label_encoder = LabelEncoder()
for col in categorical:
    label_encoder.fit(adult[col])
    adult[col] = label_encoder.transform(adult[col])

# %%
adult.sample(5)
# Out:
#        age  workclass  fnlwgt  education  education_num  marital-status  \
# 28657   46          3  465974          8              7               4
# 26772   28          3  412149          8              6               4
# 29982   17          3  132680          8              6               4
# 11920   44          6  136546          3             16               2
# 17849   39          5  107233          4              9               4
#
#        occupation  relationship  race  sex  capital gain  capital loss  \
# 28657          13             3     1    1             0             0
# 26772           4             2     1    1             0             0
# 29982           7             3     1    0             0          1602
# 11920           9             0     1    1             0          1902
# 17849           2             2     0    1             0             0
#
#        hours_per_week  native country  income
# 28657              30              38       0
# ...

# %%
fig=plt.figure(figsize=(15,6))
sns.heatmap(adult.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
variables = adult
vif = pd.DataFrame()
vif["VIF"] = [variance_inflation_factor(variables, i) for i in range(variables.shape[1])]
vif["Features"] = adult.columns
vif
# Out:
#           VIF        Features
# 0    9.105640             age
# 1    8.554133       workclass
# 2    4.071376          fnlwgt
# 3    6.075108       education
# 4   20.424720   education_num
# 5    4.257889  marital-status
# 6    3.400011      occupation
# 7    2.779594    relationship
# 8    6.945434            race
# 9    4.559185             sex
# 10   1.083966    capital gain
# 11   1.078865    capital loss
# 12  12.064174  hours_per_week
# 13  28.977933  native country
# 14   1.748658          income

# %%
sns.pairplot(adult)

# %%
import seaborn as sns
fig, axs = plt.subplots(ncols=8, nrows=2, figsize=(20, 10))
index = 0
axs = axs.flatten()
for k,v in adult.items():
    sns.boxplot(y=k, data=adult, ax=axs[index])
    index += 1
plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=5.0)

# %%
from sklearn.model_selection import train_test_split

# %%
X = adult.drop(columns ='income')
Y = adult['income']

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y , test_size = 0.15, random_state = 42)

# %%
print("X_train shape: ", x_train.shape)
print("Y_train shape: ", y_train.shape)
print("X_test shape: ", x_test.shape)
print("Y_test shape: ", y_test.shape)
# Out:
# X_train shape:  (27676, 14)
# Y_train shape:  (27676,)
# X_test shape:  (4885, 14)
# Y_test shape:  (4885,)

# %%
# fitting data to model

from sklearn.linear_model import LogisticRegression

log_reg = LogisticRegression()
log_reg.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
y_train_pred = log_reg.predict(x_train)

# %%
log_reg_train = accuracy_score(y_train, y_train_pred)
log_reg_train
# Out:
# 0.7918413065471889

# %%
# model predictions

y_pred = log_reg.predict(x_test)

# %%
# accuracy score

from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

print(accuracy_score(y_train, log_reg.predict(x_train)))

log_reg_acc = accuracy_score(y_test, y_pred)
print(log_reg_acc)
# Out:
# 0.7918413065471889
# 0.792835209825998

# %%
# Confusion Matrix
conf_mat = confusion_matrix(y_test,y_pred)
conf_mat
# Out:
# array([[3494,  189],
#        [ 823,  379]], dtype=int64)

# %%
# classification report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.95      0.87      3683
#            1       0.67      0.32      0.43      1202
#
#     accuracy                           0.79      4885
#    macro avg       0.74      0.63      0.65      4885
# weighted avg       0.77      0.79      0.76      4885

# %%
true_positive = conf_mat[0][0]
false_positive = conf_mat[0][1]
false_negative = conf_mat[1][0]
true_negative = conf_mat[1][1]

# %%
# Breaking down the formula for Accuracy
Accuracy = (true_positive + true_negative) / (true_positive +false_positive + false_negative + true_negative)
Accuracy
# Out:
# 0.792835209825998

# %%
# Precison
Precision = true_positive/(true_positive+false_positive)
Precision
# Out:
# 0.9486831387455879

# %%
# Recall
Recall = true_positive/(true_positive+false_negative)
Recall
# Out:
# 0.8093583507065092

# %%
# F1 Score
F1_Score = 2*(Recall * Precision) / (Recall + Precision)
F1_Score
# Out:
# 0.8735

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, roc_curve, roc_auc_score
# Area Under Curve
auc = roc_auc_score(y_test, y_pred)
auc
# Out:
# 0.6319954795225443

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_pred)

# %%
plt.plot(fpr, tpr, color='orange', label='ROC')
plt.plot([0, 1], [0, 1], color='darkblue', linestyle='--',label='ROC curve (area = %0.2f)' % auc)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend()
plt.show()

# %% [markdown]
# ## KNN Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier()
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_train_pred = knn.predict(x_train)

# %%
# model predictions 
y_pred = knn.predict(x_test)

# %%
# accuracy score

print(accuracy_score(y_train, y_train_pred))

knn_acc = accuracy_score(y_test, y_pred)
print(knn_acc)
# Out:
# 0.8337548778725249
# 0.7778915046059366

# %%
# confusion matrix

print(confusion_matrix(y_test, y_pred))
# Out:
# [[3397  286]
#  [ 799  403]]

# %%
# classification report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.92      0.86      3683
#            1       0.58      0.34      0.43      1202
#
#     accuracy                           0.78      4885
#    macro avg       0.70      0.63      0.64      4885
# weighted avg       0.75      0.78      0.75      4885

# %% [markdown]
# ## Naive Bayes

# %%
from sklearn.naive_bayes import BernoulliNB
classifier = BernoulliNB()
classifier.fit(x_train, y_train)
# Out:
# BernoulliNB()

# %%
y_train_pred = classifier.predict(x_train)
naive_train_score = classifier.score(y_train, y_train_pred)
naive_train_score
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [86], line 2
#       1 y_train_pred = classifier.predict(x_train)
# ----> 2 naive_train_score = classifier.score(y_train, y_train_pred)
#       3 naive_train_score
#
# File ~\anaconda3\lib\site-packages\sklearn\base.py:651, in ClassifierMixin.score(self, X, y, sample_weight)
#     626 """
#     627 Return the mean accuracy on the given test data and labels.
#     628
#    (...)
#     647     Mean accuracy of ``self.predict(X)`` wrt. `y`.
#     648 """
#     649 from .metrics import accuracy_score
# --> 651 return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#
# File ~\anaconda3\lib\site-packages\sklearn\naive_bayes.py:82, in _BaseNB.predict(self, X)
#      68 """
#      69 Perform classification on an array of test vectors X.
#      70
#    (...)
#      79     Predicted target values for X.
# ...

# %%
y_pred = classifier.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix 
from sklearn.metrics import accuracy_score 
from sklearn.metrics import classification_report 
  
results = confusion_matrix(y_test, y_pred) 
  
print ('Confusion Matrix :')
print(results) 
print ('Accuracy Score :',accuracy_score(y_test, y_pred) )
print ('Report : ')
print (classification_report(y_test, y_pred) )
# Out:
# Confusion Matrix :
# [[2744  939]
#  [ 351  851]]
# Accuracy Score : 0.7359263050153532
# Report :
#               precision    recall  f1-score   support
#
#            0       0.89      0.75      0.81      3683
#            1       0.48      0.71      0.57      1202
#
#     accuracy                           0.74      4885
#    macro avg       0.68      0.73      0.69      4885
# weighted avg       0.79      0.74      0.75      4885

# %%
score = classifier.score(x_test,y_test)*100
score
# Out:
# 73.59263050153531

# %% [markdown]
# ## Decision Tree

# %%
import graphviz
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn import tree
from IPython.display import Image  
from sklearn.tree import export_graphviz
import pydotplus

# %%
#let's first visualize the tree on the data without doing any pre processing
clf = DecisionTreeClassifier()
clf.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
feature_name=list(X.columns)
class_name = list(y_train.unique())
feature_name
# Out:
# ['age',
#  'workclass',
#  'fnlwgt',
#  'education',
#  'education_num',
#  'marital-status',
#  'occupation',
#  'relationship',
#  'race',
#  'sex',
#  'capital gain',
#  'capital loss',
#  'hours_per_week',
#  'native country']

# %%
class_name
# Out:
# [0, 1]

# %%
clf.score(x_train,y_train)
# Out:
# 0.9999638676109265

# %%
py_pred = clf.predict(x_test)

# %%
clf_score = clf.score(x_test,y_test)
clf_score
# Out:
# 0.8149437052200614
